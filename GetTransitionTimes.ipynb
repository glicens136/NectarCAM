# %%
# %%python - ServerCacoLogic.1.log
# from datetime import datetime
# import sys
#
# # getting the name of the logfile
#
# print(sys.argv)
# filename = "ServerCacoLogic.log"
#
#
# if len(sys.argv) > 2:
#     filename = sys.argv[1]
# elif len(sys.argv)==1:
#     print("Usage: GetTransitionTimes logfilename")
#     print("Using default logfile")
#
#
# delta_seconds=0
# previous_seconds=0
#
# with open(filename, encoding='utf-8') as entree:
#     for line in entree:
#         # line contient déjà un retour à la ligne
# #        print(line, end='')
#         lin2 = line.strip()
#         index = lin2.find("CaCo New State")
#         if index>0:
#             print("Present state: ",lin2[index+16:])
#             date,time_str, rest = lin2.split(maxsplit=2)
#             print("Date:", time_str)
#             t = datetime.strptime(time_str, "%H:%M:%S.%f")
#
#             total_seconds = (
#                 t.hour * 3600 +
#                 t.minute * 60 +
#                 t.second +
#                 t.microsecond / 1_000_000
#             )
#             print("Time in seconds:", total_seconds)
#             delta_seconds = total_seconds-previous_seconds
#             print("Transition time:", delta_seconds)
#             previous_seconds = total_seconds
# Out:
# ['-', 'ServerCacoLogic.1.log']
# Present state:  OFF
# Date: 12:31:57.466
# Time in seconds: 45117.466
# Transition time: 45117.466
# Present state:  TRANSITIONAL
# Date: 12:32:11.271
# Time in seconds: 45131.271
# Transition time: 13.805000000000291
# Present state:  UNDEFINED (Previous State: OFF)
# Date: 12:32:23.950
# Time in seconds: 45143.95
# Transition time: 12.67899999999645
# Present state:  SAFE (Previous State: OFF)
# Date: 12:32:51.142
# Time in seconds: 45171.142
# Transition time: 27.192000000002736
# Present state:  SAFE (Previous State: OFF)
# Date: 12:33:45.378
# Time in seconds: 45225.378
# Transition time: 54.23599999999715
# Present state:  TRANSITIONAL
# Date: 12:33:51.628
# Time in seconds: 45231.628
# Transition time: 6.25
# Present state:  SAFE (Previous State: OFF)
# Date: 12:33:51.633
# Time in seconds: 45231.633
# Transition time: 0.005000000004656613
# Present state:  TRANSITIONAL
# Date: 12:35:26.119
# Time in seconds: 45326.119
# Transition time: 94.48599999999715
# Present state:  STANDBY (Previous State: SAFE)
# Date: 12:39:41.983
# Time in seconds: 45581.983
# Transition time: 255.8640000000014
# Present state:  UNDEFINED (Previous State: SAFE)
# Date: 12:45:58.183
# Time in seconds: 45958.183
# Transition time: 376.1999999999971
# Present state:  UNDEFINED (Previous State: SAFE)
# Date: 12:46:38.174
# Time in seconds: 45998.174
# Transition time: 39.991000000001804
# Present state:  STANDBY (Previous State: SAFE)
# Date: 12:47:04.263
# Time in seconds: 46024.263
# Transition time: 26.088999999999942
# Present state:  TRANSITIONAL
# Date: 12:49:16.464
# Time in seconds: 46156.464
# Transition time: 132.20100000000093
# Present state:  STANDBY (Previous State: SAFE)
# Date: 12:49:17.486
# Time in seconds: 46157.486
# Transition time: 1.021999999997206
# Present state:  TRANSITIONAL
# Date: 13:01:29.888
# Time in seconds: 46889.888
# Transition time: 732.4020000000019
# Present state:  UNDEFINED (Previous State: STANDBY)
# Date: 13:02:32.412
# Time in seconds: 46952.412
# Transition time: 62.52399999999761
# Present state:  TRANSITIONAL
# Date: 13:07:13.593
# Time in seconds: 47233.593
# Transition time: 281.18100000000413
# Present state:  SAFE (Previous State: UNDEFINED)
# Date: 13:07:24.567
# Time in seconds: 47244.567
# Transition time: 10.974000000001979
# Present state:  OFF
# Date: 13:23:45.063
# Time in seconds: 48225.063
# Transition time: 980.4959999999992
# Present state:  TRANSITIONAL
# Date: 13:24:52.227
# Time in seconds: 48292.227
# Transition time: 67.16399999999703
# Present state:  SAFE (Previous State: OFF)
# Date: 13:25:10.126
# Time in seconds: 48310.126
# Transition time: 17.898999999997613
# Present state:  SAFE (Previous State: OFF)
# Date: 13:25:13.848
# Time in seconds: 48313.848
# Transition time: 3.7220000000015716
# Present state:  TRANSITIONAL
# Date: 13:25:17.307
# Time in seconds: 48317.307
# Transition time: 3.459000000002561
# Present state:  STANDBY (Previous State: SAFE)
# Date: 13:29:26.165
# Time in seconds: 48566.165
# Transition time: 248.85800000000017
# Present state:  TRANSITIONAL
# Date: 13:31:19.841
# Time in seconds: 48679.841
# Transition time: 113.67599999999948
# Present state:  STANDBY (Previous State: SAFE)
# Date: 13:31:43.776
# Time in seconds: 48703.776
# Transition time: 23.93499999999767
# Present state:  TRANSITIONAL
# Date: 13:34:23.204
# Time in seconds: 48863.204
# Transition time: 159.42799999999988
# Present state:  STANDBY (Previous State: SAFE)
# Date: 13:34:24.230
# Time in seconds: 48864.23
# Transition time: 1.026000000005297
# Present state:  TRANSITIONAL
# Date: 13:36:52.572
# Time in seconds: 49012.572
# Transition time: 148.34199999999691
# Present state:  STANDBY (Previous State: SAFE)
# Date: 13:36:53.599
# Time in seconds: 49013.599
# Transition time: 1.0270000000018626
# Present state:  TRANSITIONAL
# Date: 13:39:37.841
# Time in seconds: 49177.841
# Transition time: 164.24199999999837
# Present state:  STANDBY (Previous State: SAFE)
# Date: 13:40:01.789
# Time in seconds: 49201.789
# Transition time: 23.947999999996682
# Present state:  TRANSITIONAL
# Date: 13:42:51.143
# Time in seconds: 49371.143
# Transition time: 169.35399999999936
# Present state:  UNDEFINED (Previous State: STANDBY)
# Date: 13:43:51.880
# Time in seconds: 49431.88
# Transition time: 60.73700000000099
# Present state:  TRANSITIONAL
# Date: 13:44:05.976
# Time in seconds: 49445.976
# Transition time: 14.096000000005006
# Present state:  SAFE (Previous State: UNDEFINED)
# Date: 13:44:16.906
# Time in seconds: 49456.906
# Transition time: 10.930000000000291
# Present state:  OFF
# Date: 14:12:30.606
# Time in seconds: 51150.606
# Transition time: 1693.699999999997
# Present state:  TRANSITIONAL
# Date: 14:16:22.532
# Time in seconds: 51382.532
# Transition time: 231.92599999999948
# Present state:  SAFE (Previous State: OFF)
# Date: 14:16:22.537
# Time in seconds: 51382.537
# Transition time: 0.004999999997380655
# Present state:  TRANSITIONAL
# Date: 14:16:31.943
# Time in seconds: 51391.943
# Transition time: 9.406000000002678
# Present state:  SAFE (Previous State: OFF)
# Date: 14:16:31.949
# Time in seconds: 51391.949
# Transition time: 0.006000000001222361
# Present state:  TRANSITIONAL
# Date: 14:18:10.373
# Time in seconds: 51490.373
# Transition time: 98.42399999999907
# Present state:  SAFE (Previous State: OFF)
# Date: 14:18:10.377
# Time in seconds: 51490.377
# Transition time: 0.004000000000814907
# Present state:  OFF
# Date: 14:19:36.550
# Time in seconds: 51576.55
# Transition time: 86.1730000000025
# Present state:  TRANSITIONAL
# Date: 14:19:54.137
# Time in seconds: 51594.137
# Transition time: 17.586999999999534
# Present state:  OFF (Previous State: OFF)
# Date: 14:19:54.143
# Time in seconds: 51594.143
# Transition time: 0.005999999993946403
# Present state:  TRANSITIONAL
# Date: 14:20:01.641
# Time in seconds: 51601.641
# Transition time: 7.4980000000068685
# Present state:  OFF (Previous State: OFF)
# Date: 14:20:01.644
# Time in seconds: 51601.644
# Transition time: 0.0029999999969732016
# Present state:  TRANSITIONAL
# Date: 14:20:33.318
# Time in seconds: 51633.318
# Transition time: 31.67399999999907
# Present state:  OFF (Previous State: OFF)
# Date: 14:20:33.319
# Time in seconds: 51633.319
# Transition time: 0.0010000000038417056
# Present state:  OFF
# Date: 08:34:37.601
# Time in seconds: 30877.601
# Transition time: -20755.718000000004
# Present state:  TRANSITIONAL
# Date: 08:42:35.467
# Time in seconds: 31355.467
# Transition time: 477.8660000000018
# Present state:  SAFE (Previous State: OFF)
# Date: 08:42:35.477
# Time in seconds: 31355.477
# Transition time: 0.00999999999839929
# Present state:  TRANSITIONAL
# Date: 08:47:40.519
# Time in seconds: 31660.519
# Transition time: 305.0420000000013
# Present state:  SAFE (Previous State: OFF)
# Date: 08:47:40.525
# Time in seconds: 31660.525
# Transition time: 0.006000000001222361
# Present state:  TRANSITIONAL
# Date: 08:49:07.095
# Time in seconds: 31747.095
# Transition time: 86.56999999999971
# Present state:  SAFE (Previous State: OFF)
# Date: 08:49:07.097
# Time in seconds: 31747.097
# Transition time: 0.0020000000004074536
# Present state:  OFF
# Date: 10:29:50.509
# Time in seconds: 37790.509
# Transition time: 6043.411999999997
# Present state:  TRANSITIONAL
# Date: 10:31:27.384
# Time in seconds: 37887.384
# Transition time: 96.875
# Present state:  UNDEFINED (Previous State: OFF)
# Date: 10:31:52.724
# Time in seconds: 37912.724
# Transition time: 25.340000000003783
# Present state:  TRANSITIONAL
# Date: 10:35:49.290
# Time in seconds: 38149.29
# Transition time: 236.5659999999989
# Present state:  SAFE (Previous State: UNDEFINED)
# Date: 10:36:08.694
# Time in seconds: 38168.694
# Transition time: 19.40400000000227
# Present state:  OFF
# Date: 10:43:13.858
# Time in seconds: 38593.858
# Transition time: 425.16399999999703
# Present state:  TRANSITIONAL
# Date: 10:44:50.541
# Time in seconds: 38690.541
# Transition time: 96.68299999999726
# Present state:  SAFE (Previous State: OFF)
# Date: 10:45:09.472
# Time in seconds: 38709.472
# Transition time: 18.931000000004133
# Present state:  SAFE (Previous State: OFF)
# Date: 10:45:11.214
# Time in seconds: 38711.214
# Transition time: 1.7419999999983702
